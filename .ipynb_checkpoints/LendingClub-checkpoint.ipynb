# %% [markdown]
# # 目录

# %% [markdown]
# 1. [简介](#intro)
# 2. [数据介绍](#data)
# 3. [目标变量](#targetvariable)
# 4. [特征选择一：EDA](#featureselection)<br>
#     4.1 [过滤掉缺失率很高的特征](#missing_data)<br>
#     4.2 [剔除掉无关数据](#cheat_data)<br>
#     4.3 [逐一分析剩余特征](#inspect)<br>
# 5. [特征选择二：基于统计的观点](#corr)<br>
#     5.1 [转换目标变量](#converttarget)<br>
#     5.2 [假设检验](#kstest)<br>
#     5.3 [皮尔森系数和热力图](#pearson)<br>
# 6. [特征工程](#feature)<br>
#     6.1 [独热编码](#dummies)<br>
#     6.2 [数据分割](#split)<br>
#     6.3 [缺失值填充](#imputing)<br>
#     6.4 [归一化](#scaling)<br>
#     6.5 [PCA](#pca)<br>
#     6.6 [现行相关](#pearson2)<br>
# 7. [Modeling](#modeling)<br>
#     7.1 [逻辑回归](#logreg)<br>
#     7.2 [XGBoost](#xgb)<br>
#     7.3 [LightGBM](#lgb)<br>
#     7.4 [KNN](#knn)<br>
#     7.5 [使用ROC和混淆矩阵进行模型评估](#evaluate)<br>
# 8. [结论](#conclusion)<br>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
sns.set_style('whitegrid')
# %matplotlib inline

from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC, LinearSVC
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import roc_auc_score,confusion_matrix
from scipy.stats import ks_2samp
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
import warnings
#warnings.filterwarnings("ignore", category=DeprecationWarning,RuntimeWarning) 
warnings.filterwarnings("ignore") 


pd.set_option('display.max_columns', None)

# %% [markdown]
# ## 1. 简介
# <a id="intro"></a>
# 本项目目标是构建一个贷款违约预测模型，本项目使用Lending Club数据，我们希望构建一个模型帮助操作员决策。且模型是可解释和精准的。数据集来

# %% [markdown]
# ## 2. 数据

# %% [markdown]
# 在这个项目中，我们使用[kaggle](https://www.kaggle.com/wordsforthewise/lending-club)s上的公开的数据。数据量包括2007年到2018年的贷款数据。总的数量有226万，151个特征

# %%
df = pd.read_csv("data/accepted_2007_to_2018Q4.csv", low_memory=False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2260701 entries, 0 to 2260700
# Columns: 151 entries, id to settlement_term
# dtypes: float64(113), object(38)
# memory usage: 2.5+ GB

# %%
df.head()
# Out:
#          id  member_id  loan_amnt  funded_amnt  funded_amnt_inv        term  \
# 0  68407277        NaN     3600.0       3600.0           3600.0   36 months
# 1  68355089        NaN    24700.0      24700.0          24700.0   36 months
# 2  68341763        NaN    20000.0      20000.0          20000.0   60 months
# 3  66310712        NaN    35000.0      35000.0          35000.0   60 months
# 4  68476807        NaN    10400.0      10400.0          10400.0   60 months
#
#    int_rate  installment grade sub_grade                    emp_title  \
# 0     13.99       123.03     C        C4                      leadman
# 1     11.99       820.28     C        C1                     Engineer
# 2     10.78       432.66     B        B4                 truck driver
# 3     14.85       829.90     C        C5  Information Systems Officer
# 4     22.45       289.91     F        F1          Contract Specialist
#
#   emp_length home_ownership  annual_inc verification_status   issue_d  \
# 0  10+ years       MORTGAGE     55000.0        Not Verified  Dec-2015
# 1  10+ years       MORTGAGE     65000.0        Not Verified  Dec-2015
# 2  10+ years       MORTGAGE     63000.0        Not Verified  Dec-2015
# 3  10+ years       MORTGAGE    110000.0     Source Verified  Dec-2015
# 4    3 years       MORTGAGE    104433.0     Source Verified  Dec-2015
#
#   loan_status pymnt_plan                                                url  \
# 0  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 1  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 2  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
# 3     Current          n  https://lendingclub.com/browse/loanDetail.acti...
# 4  Fully Paid          n  https://lendingclub.com/browse/loanDetail.acti...
#
#   desc             purpose               title zip_code addr_state    dti  \
# 0  NaN  debt_consolidation  Debt consolidation    190xx         PA   5.91
# 1  NaN      small_business            Business    577xx         SD  16.06
# 2  NaN    home_improvement                 NaN    605xx         IL  10.78
# 3  NaN  debt_consolidation  Debt consolidation    076xx         NJ  17.06
# 4  NaN      major_purchase      Major purchase    174xx         PA  25.37
#
#    delinq_2yrs earliest_cr_line  fico_range_low  fico_range_high  \
# 0          0.0         Aug-2003           675.0            679.0
# 1          1.0         Dec-1999           715.0            719.0
# 2          0.0         Aug-2000           695.0            699.0
# 3          0.0         Sep-2008           785.0            789.0
# 4          1.0         Jun-1998           695.0            699.0
#
#    inq_last_6mths  mths_since_last_delinq  mths_since_last_record  open_acc  \
# 0             1.0                    30.0                     NaN       7.0
# 1             4.0                     6.0                     NaN      22.0
# 2             0.0                     NaN                     NaN       6.0
# 3             0.0                     NaN                     NaN      13.0
# 4             3.0                    12.0                     NaN      12.0
#
#    pub_rec  revol_bal  revol_util  total_acc initial_list_status  out_prncp  \
# 0      0.0     2765.0        29.7       13.0                   w       0.00
# 1      0.0    21470.0        19.2       38.0                   w       0.00
# 2      0.0     7869.0        56.2       18.0                   w       0.00
# 3      0.0     7802.0        11.6       17.0                   w   15897.65
# 4      0.0    21929.0        64.5       35.0                   w       0.00
#
#    out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0           0.00   4421.723917          4421.72          3600.00
# 1           0.00  25679.660000         25679.66         24700.00
# 2           0.00  22705.924294         22705.92         20000.00
# 3       15897.65  31464.010000         31464.01         19102.35
# 4           0.00  11740.500000         11740.50         10400.00
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0         821.72                 0.0         0.0                      0.0
# 1         979.66                 0.0         0.0                      0.0
# 2        2705.92                 0.0         0.0                      0.0
# 3       12361.66                 0.0         0.0                      0.0
# 4        1340.50                 0.0         0.0                      0.0
#
#   last_pymnt_d  last_pymnt_amnt next_pymnt_d last_credit_pull_d  \
# 0     Jan-2019           122.67          NaN           Mar-2019
# 1     Jun-2016           926.35          NaN           Mar-2019
# 2     Jun-2017         15813.30          NaN           Mar-2019
# 3     Feb-2019           829.90     Apr-2019           Mar-2019
# 4     Jul-2016         10128.96          NaN           Mar-2018
#
#    last_fico_range_high  last_fico_range_low  collections_12_mths_ex_med  \
# 0                 564.0                560.0                         0.0
# 1                 699.0                695.0                         0.0
# 2                 704.0                700.0                         0.0
# 3                 679.0                675.0                         0.0
# 4                 704.0                700.0                         0.0
#
#    mths_since_last_major_derog  policy_code application_type  \
# 0                         30.0          1.0       Individual
# 1                          NaN          1.0       Individual
# 2                          NaN          1.0        Joint App
# 3                          NaN          1.0       Individual
# 4                          NaN          1.0       Individual
#
#    annual_inc_joint  dti_joint verification_status_joint  acc_now_delinq  \
# 0               NaN        NaN                       NaN             0.0
# 1               NaN        NaN                       NaN             0.0
# 2           71000.0      13.85              Not Verified             0.0
# 3               NaN        NaN                       NaN             0.0
# 4               NaN        NaN                       NaN             0.0
#
#    tot_coll_amt  tot_cur_bal  open_acc_6m  open_act_il  open_il_12m  \
# 0         722.0     144904.0          2.0          2.0          0.0
# 1           0.0     204396.0          1.0          1.0          0.0
# 2           0.0     189699.0          0.0          1.0          0.0
# 3           0.0     301500.0          1.0          1.0          0.0
# 4           0.0     331730.0          1.0          3.0          0.0
#
#    open_il_24m  mths_since_rcnt_il  total_bal_il  il_util  open_rv_12m  \
# 0          1.0                21.0        4981.0     36.0          3.0
# 1          1.0                19.0       18005.0     73.0          2.0
# 2          4.0                19.0       10827.0     73.0          0.0
# 3          1.0                23.0       12609.0     70.0          1.0
# 4          3.0                14.0       73839.0     84.0          4.0
#
#    open_rv_24m  max_bal_bc  all_util  total_rev_hi_lim  inq_fi  total_cu_tl  \
# 0          3.0       722.0      34.0            9300.0     3.0          1.0
# 1          3.0      6472.0      29.0          111800.0     0.0          0.0
# 2          2.0      2081.0      65.0           14000.0     2.0          5.0
# 3          1.0      6987.0      45.0           67300.0     0.0          1.0
# 4          7.0      9702.0      78.0           34000.0     2.0          1.0
#
#    inq_last_12m  acc_open_past_24mths  avg_cur_bal  bc_open_to_buy  bc_util  \
# 0           4.0                   4.0      20701.0          1506.0     37.2
# 1           6.0                   4.0       9733.0         57830.0     27.1
# 2           1.0                   6.0      31617.0          2737.0     55.9
# 3           0.0                   2.0      23192.0         54962.0     12.1
# 4           3.0                  10.0      27644.0          4567.0     77.5
#
#    chargeoff_within_12_mths  delinq_amnt  mo_sin_old_il_acct  \
# 0                       0.0          0.0               148.0
# 1                       0.0          0.0               113.0
# 2                       0.0          0.0               125.0
# 3                       0.0          0.0                36.0
# 4                       0.0          0.0               128.0
#
#    mo_sin_old_rev_tl_op  mo_sin_rcnt_rev_tl_op  mo_sin_rcnt_tl  mort_acc  \
# 0                 128.0                    3.0             3.0       1.0
# 1                 192.0                    2.0             2.0       4.0
# 2                 184.0                   14.0            14.0       5.0
# 3                  87.0                    2.0             2.0       1.0
# 4                 210.0                    4.0             4.0       6.0
#
#    mths_since_recent_bc  mths_since_recent_bc_dlq  mths_since_recent_inq  \
# 0                   4.0                      69.0                    4.0
# 1                   2.0                       NaN                    0.0
# 2                 101.0                       NaN                   10.0
# 3                   2.0                       NaN                    NaN
# 4                   4.0                      12.0                    1.0
#
#    mths_since_recent_revol_delinq  num_accts_ever_120_pd  num_actv_bc_tl  \
# 0                            69.0                    2.0             2.0
# 1                             6.0                    0.0             5.0
# 2                             NaN                    0.0             2.0
# 3                             NaN                    0.0             4.0
# 4                            12.0                    0.0             4.0
#
#    num_actv_rev_tl  num_bc_sats  num_bc_tl  num_il_tl  num_op_rev_tl  \
# 0              4.0          2.0        5.0        3.0            4.0
# 1              5.0         13.0       17.0        6.0           20.0
# 2              3.0          2.0        4.0        6.0            4.0
# 3              5.0          8.0       10.0        2.0           10.0
# 4              6.0          5.0        9.0       10.0            7.0
#
#    num_rev_accts  num_rev_tl_bal_gt_0  num_sats  num_tl_120dpd_2m  \
# 0            9.0                  4.0       7.0               0.0
# 1           27.0                  5.0      22.0               0.0
# 2            7.0                  3.0       6.0               0.0
# 3           13.0                  5.0      13.0               0.0
# 4           19.0                  6.0      12.0               0.0
#
#    num_tl_30dpd  num_tl_90g_dpd_24m  num_tl_op_past_12m  pct_tl_nvr_dlq  \
# 0           0.0                 0.0                 3.0            76.9
# 1           0.0                 0.0                 2.0            97.4
# 2           0.0                 0.0                 0.0           100.0
# 3           0.0                 0.0                 1.0           100.0
# 4           0.0                 0.0                 4.0            96.6
#
#    percent_bc_gt_75  pub_rec_bankruptcies  tax_liens  tot_hi_cred_lim  \
# 0               0.0                   0.0        0.0         178050.0
# 1               7.7                   0.0        0.0         314017.0
# 2              50.0                   0.0        0.0         218418.0
# 3               0.0                   0.0        0.0         381215.0
# 4              60.0                   0.0        0.0         439570.0
#
#    total_bal_ex_mort  total_bc_limit  total_il_high_credit_limit  \
# 0             7746.0          2400.0                     13734.0
# 1            39475.0         79300.0                     24667.0
# 2            18696.0          6200.0                     14877.0
# 3            52226.0         62500.0                     18000.0
# 4            95768.0         20300.0                     88097.0
#
#    revol_bal_joint  sec_app_fico_range_low  sec_app_fico_range_high  \
# 0              NaN                     NaN                      NaN
# 1              NaN                     NaN                      NaN
# 2              NaN                     NaN                      NaN
# 3              NaN                     NaN                      NaN
# 4              NaN                     NaN                      NaN
#
#   sec_app_earliest_cr_line  sec_app_inq_last_6mths  sec_app_mort_acc  \
# 0                      NaN                     NaN               NaN
# 1                      NaN                     NaN               NaN
# 2                      NaN                     NaN               NaN
# 3                      NaN                     NaN               NaN
# 4                      NaN                     NaN               NaN
#
#    sec_app_open_acc  sec_app_revol_util  sec_app_open_act_il  \
# 0               NaN                 NaN                  NaN
# 1               NaN                 NaN                  NaN
# 2               NaN                 NaN                  NaN
# 3               NaN                 NaN                  NaN
# 4               NaN                 NaN                  NaN
#
#    sec_app_num_rev_accts  sec_app_chargeoff_within_12_mths  \
# 0                    NaN                               NaN
# 1                    NaN                               NaN
# 2                    NaN                               NaN
# 3                    NaN                               NaN
# 4                    NaN                               NaN
#
#    sec_app_collections_12_mths_ex_med  sec_app_mths_since_last_major_derog  \
# 0                                 NaN                                  NaN
# 1                                 NaN                                  NaN
# 2                                 NaN                                  NaN
# 3                                 NaN                                  NaN
# 4                                 NaN                                  NaN
#
#   hardship_flag hardship_type hardship_reason hardship_status  deferral_term  \
# 0             N           NaN             NaN             NaN            NaN
# 1             N           NaN             NaN             NaN            NaN
# 2             N           NaN             NaN             NaN            NaN
# 3             N           NaN             NaN             NaN            NaN
# 4             N           NaN             NaN             NaN            NaN
#
#    hardship_amount hardship_start_date hardship_end_date  \
# 0              NaN                 NaN               NaN
# 1              NaN                 NaN               NaN
# 2              NaN                 NaN               NaN
# 3              NaN                 NaN               NaN
# 4              NaN                 NaN               NaN
#
#   payment_plan_start_date  hardship_length  hardship_dpd hardship_loan_status  \
# 0                     NaN              NaN           NaN                  NaN
# 1                     NaN              NaN           NaN                  NaN
# 2                     NaN              NaN           NaN                  NaN
# 3                     NaN              NaN           NaN                  NaN
# 4                     NaN              NaN           NaN                  NaN
#
#    orig_projected_additional_accrued_interest  hardship_payoff_balance_amount  \
# 0                                         NaN                             NaN
# 1                                         NaN                             NaN
# 2                                         NaN                             NaN
# 3                                         NaN                             NaN
# 4                                         NaN                             NaN
#
#    hardship_last_payment_amount disbursement_method debt_settlement_flag  \
# 0                           NaN                Cash                    N
# 1                           NaN                Cash                    N
# 2                           NaN                Cash                    N
# 3                           NaN                Cash                    N
# 4                           NaN                Cash                    N
#
#   debt_settlement_flag_date settlement_status settlement_date  \
# 0                       NaN               NaN             NaN
# 1                       NaN               NaN             NaN
# 2                       NaN               NaN             NaN
# 3                       NaN               NaN             NaN
# 4                       NaN               NaN             NaN
#
#    settlement_amount  settlement_percentage  settlement_term
# 0                NaN                    NaN              NaN
# 1                NaN                    NaN              NaN
# 2                NaN                    NaN              NaN
# 3                NaN                    NaN              NaN
# 4                NaN                    NaN              NaN

# %% [markdown]
# ## 3. 目标变量
# <a id="targetvariable"></a>

# %% [markdown]
# 我们首先要了解一下目标变量的情况，以便于我们对数据分布有个整体把控

# %%
df["loan_status"].value_counts()
# Out:
# Fully Paid                                             1076751
# Current                                                 878317
# Charged Off                                             268559
# Late (31-120 days)                                       21467
# In Grace Period                                           8436
# Late (16-30 days)                                         4349
# Does not meet the credit policy. Status:Fully Paid        1988
# Does not meet the credit policy. Status:Charged Off        761
# Default                                                     40
# Name: loan_status, dtype: int64

# %% [markdown]
# 我们之分析两种情况，坏账(Charged off)和结清(Fully Paid)的情况，至于其他的状态我们不做考虑

# %%
df = df.loc[df['loan_status'].isin(['Fully Paid','Charged Off'])]

# %%
df['loan_status'].value_counts(normalize=False, dropna=False)
# Out:
# Fully Paid     1076751
# Charged Off     268559
# Name: loan_status, dtype: int64

# %%
df['loan_status'].value_counts(normalize=True, dropna=False)
# Out:
# Fully Paid     0.800374
# Charged Off    0.199626
# Name: loan_status, dtype: float64

# %% [markdown]
# 正负样本比例约为4:1由此可见，这是一个不平衡问题

# %% [markdown]
# ## 4. 特征选择一
# <a id="featureselection"></a>

# %% [markdown]
# 原始数据包含很多缺失值，我们剔除那些缺失比例超过50%的特征然后做一些特征类型转化

# %% [markdown]
# ### 4.1 过滤掉缺失值很高的特征
# <a id="missing_data"></a>

# %%
#统计缺失值分布
mis_val_per = df.isnull().sum()/len(df)

#数据类型统计
mis_val_type = df.dtypes

mis_table = pd.concat([mis_val_per,mis_val_type],axis=1)
mis_table.columns = ["缺失率","类型"]
mis_table
# Out:
#                             缺失率       类型
# id                     0.000000   object
# member_id              1.000000  float64
# loan_amnt              0.000000  float64
# funded_amnt            0.000000  float64
# funded_amnt_inv        0.000000  float64
# ...                         ...      ...
# settlement_status      0.975265   object
# settlement_date        0.975265   object
# settlement_amount      0.975265  float64
# settlement_percentage  0.975265  float64
# settlement_term        0.975265  float64
#
# [151 rows x 2 columns]

# %%
drop_list = mis_table[mis_table["缺失率"]>0.5].index.tolist()

# %%
len(drop_list)
# Out:
# 58

# %%
#剔除缺失率高的特征
df.drop(drop_list,axis=1,inplace=True)

# %% [markdown]
# ### 4.2 剔除无关变量
# <a id="cheat_data"></a>

# %% [markdown]
# 本项目是基于贷款申请人的特征，申请成功之后的行为特征不予考虑

# %%
df.columns.tolist()
# Out:
# ['id',
#  'loan_amnt',
#  'funded_amnt',
#  'funded_amnt_inv',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'pymnt_plan',
#  'url',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'delinq_2yrs',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'inq_last_6mths',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'out_prncp',
#  'out_prncp_inv',
#  'total_pymnt',
#  'total_pymnt_inv',
#  'total_rec_prncp',
#  'total_rec_int',
#  'total_rec_late_fee',
#  'recoveries',
#  'collection_recovery_fee',
#  'last_pymnt_d',
#  'last_pymnt_amnt',
#  'last_credit_pull_d',
#  'last_fico_range_high',
#  'last_fico_range_low',
#  'collections_12_mths_ex_med',
#  'policy_code',
#  'application_type',
#  'acc_now_delinq',
#  'tot_coll_amt',
#  'tot_cur_bal',
#  'total_rev_hi_lim',
#  'acc_open_past_24mths',
#  'avg_cur_bal',
#  'bc_open_to_buy',
#  'bc_util',
#  'chargeoff_within_12_mths',
#  'delinq_amnt',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mo_sin_rcnt_rev_tl_op',
#  'mo_sin_rcnt_tl',
#  'mort_acc',
#  'mths_since_recent_bc',
#  'mths_since_recent_inq',
#  'num_accts_ever_120_pd',
#  'num_actv_bc_tl',
#  'num_actv_rev_tl',
#  'num_bc_sats',
#  'num_bc_tl',
#  'num_il_tl',
#  'num_op_rev_tl',
#  'num_rev_accts',
#  'num_rev_tl_bal_gt_0',
#  'num_sats',
#  'num_tl_120dpd_2m',
#  'num_tl_30dpd',
#  'num_tl_90g_dpd_24m',
#  'num_tl_op_past_12m',
#  'pct_tl_nvr_dlq',
#  'percent_bc_gt_75',
#  'pub_rec_bankruptcies',
#  'tax_liens',
#  'tot_hi_cred_lim',
#  'total_bal_ex_mort',
#  'total_bc_limit',
#  'total_il_high_credit_limit',
#  'hardship_flag',
#  'disbursement_method',
#  'debt_settlement_flag']

# %%
drop_list = ['acc_now_delinq', 'acc_open_past_24mths', 'avg_cur_bal', 'bc_open_to_buy', 'bc_util', 'chargeoff_within_12_mths', 'collection_recovery_fee', 'collections_12_mths_ex_med', 'debt_settlement_flag', 'delinq_2yrs', 'delinq_amnt', 'disbursement_method', 'funded_amnt', 'funded_amnt_inv', 'hardship_flag', 'inq_last_6mths', 'last_credit_pull_d', 'last_fico_range_high', 'last_fico_range_low', 'last_pymnt_amnt', 'last_pymnt_d', 'mo_sin_rcnt_rev_tl_op', 'mo_sin_rcnt_tl', 'mths_since_recent_bc', 'mths_since_recent_inq', 'num_accts_ever_120_pd', 'num_actv_bc_tl', 'num_actv_rev_tl', 'num_bc_sats', 'num_bc_tl', 'num_il_tl', 'num_op_rev_tl', 'num_rev_accts', 'num_rev_tl_bal_gt_0', 'num_sats', 'num_tl_120dpd_2m', 'num_tl_30dpd', 'num_tl_90g_dpd_24m', 'num_tl_op_past_12m',  'out_prncp', 'out_prncp_inv', 'pct_tl_nvr_dlq', 'percent_bc_gt_75', 'pymnt_plan', 'recoveries', 'tax_liens', 'tot_coll_amt', 'tot_cur_bal', 'tot_hi_cred_lim', 'total_bal_ex_mort', 'total_bc_limit', 'total_il_high_credit_limit', 'total_pymnt', 'total_pymnt_inv', 'total_rec_int', 'total_rec_late_fee', 'total_rec_prncp', 'total_rev_hi_lim']

# %%
df.drop(drop_list,axis=1,inplace=True)

# %%
df.columns.to_list()
# Out:
# ['id',
#  'loan_amnt',
#  'term',
#  'int_rate',
#  'installment',
#  'grade',
#  'sub_grade',
#  'emp_title',
#  'emp_length',
#  'home_ownership',
#  'annual_inc',
#  'verification_status',
#  'issue_d',
#  'loan_status',
#  'url',
#  'purpose',
#  'title',
#  'zip_code',
#  'addr_state',
#  'dti',
#  'earliest_cr_line',
#  'fico_range_low',
#  'fico_range_high',
#  'open_acc',
#  'pub_rec',
#  'revol_bal',
#  'revol_util',
#  'total_acc',
#  'initial_list_status',
#  'policy_code',
#  'application_type',
#  'mo_sin_old_il_acct',
#  'mo_sin_old_rev_tl_op',
#  'mort_acc',
#  'pub_rec_bankruptcies']

# %%
len(df.columns)
# Out:
# 35

# %% [markdown]
# ### 4.3 逐一分析剩余特征
# <a id="inspect"></a>
#
# 我们现在有35个特征，然后我们对探索每个特针，然后决定是否需要提出他。
#
# 这个阶段我们需要做的任务是：
#
# - 逐一分析目标变量与其他特征的关系然后可视化
# - 删除没用的特征 例如 id
# - 整理数据
# - 特征转化

# %%
def feature_plot(col_name, full_name, continuous):
    fig, (ax1, ax2) = plt.subplots(1,2,sharex=False, figsize=(15,3))
    # plot1: 变量值的分布情况
    if continuous:
        sns.distplot(df.loc[df[col_name].notnull(), col_name], kde=False, ax=ax1)
    else:
        sns.countplot(df[col_name], order=sorted(df[col_name].unique()), color='#5975A4', saturation=1, ax=ax1)
    ax1.set_xlabel(full_name)
    ax1.set_ylabel('Count')
    ax1.set_title(full_name)
    
    # 绘制目标变量的分组
    if continuous:
        sns.boxplot(x=col_name, y='loan_status', data=df, ax=ax2)
        ax2.set_ylabel('')
        ax2.set_title(full_name + ' by Loan Status')
    else:
        Charged_Off_rates = df.groupby(col_name)['loan_status'].value_counts(normalize=True)[:,'Charged Off']
        sns.barplot(x=Charged_Off_rates.index, y=Charged_Off_rates.values, color='#5975A4', saturation=1, ax=ax2)
        ax2.set_ylabel('Fraction of Loans Charged Off')
        ax2.set_title('Charged Off Rate by ' + full_name)
        ax2.set_xlabel(full_name)
    
    # plot3: 分组分布情况
    if continuous:  
        facet = sns.FacetGrid(df, hue = 'loan_status', size=3, aspect=4)
        facet.map(sns.kdeplot, col_name, shade=True)
        #facet.set(xlim=(df[col_name].min(), df[col_name].max()))
        facet.add_legend()  
    else:
        fig = plt.figure(figsize=(12,3))
        sns.countplot(x=col_name, hue='loan_status', data=df, order=sorted(df[col_name].unique()) )
     
    plt.tight_layout()

# %% [markdown]
# ### issue_d
#
# **字段描述**:申请批准的日期（月）
# 这个字段本来不是贷前产生的特征，我们先保留这，之后在数据分割的时候提出该特征

# %% [markdown]
# ### id
# 这个特征我们需要删除，id并很好的反映申请的特征

# %%
df["loan_amnt"].describe()
# Out:
# count    1.345310e+06
# mean     1.441997e+04
# std      8.717051e+03
# min      5.000000e+02
# 25%      8.000000e+03
# 50%      1.200000e+04
# 75%      2.000000e+04
# max      4.000000e+04
# Name: loan_amnt, dtype: float64

# %%
feature_plot("loan_amnt", "Loan Amount", continuous=True)

# %% [markdown]
# 从图的结果来看， 坏账的申请者申请的金额比已经结清的人比较多，我们之后从统计的观点进一步分析这个特征

# %% [markdown]
# ### term
# 字段描述：
# 还款周期，可选为36个月和60个月

# %%
df['term'].sample(5)
# Out:
# 1498857     36 months
# 1309256     36 months
# 946091      36 months
# 982461      36 months
# 1990813     36 months
# Name: term, dtype: object

# %%
df['term'].value_counts(dropna=False)
# Out:
#  36 months    1020743
#  60 months     324567
# Name: term, dtype: int64

# %%
df['term'] = df['term'].apply(lambda s: np.int8(s.split()[0]))

# %%
feature_plot('term', 'Term', continuous=False)

# %%
df["term"].value_counts(normalize=True)
# Out:
# 36    0.758742
# 60    0.241258
# Name: term, dtype: float64

# %% [markdown]
# 大约有76%的贷款是选择36期的还款方式，其余的24%的为60期的还款方式，结果上看，60期的坏账比例较高

# %%
#查看坏账中30和60期的占比
df.groupby('term')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off']
# Out:
# term
# 36    0.159934
# 60    0.324454
# Name: loan_status, dtype: float64

# %% [markdown]
# ### int_rate
# 字段描述：贷款利息

# %%
df['int_rate'].describe()
# Out:
# count    1.345310e+06
# mean     1.323962e+01
# std      4.768716e+00
# min      5.310000e+00
# 25%      9.750000e+00
# 50%      1.274000e+01
# 75%      1.599000e+01
# max      3.099000e+01
# Name: int_rate, dtype: float64

# %% [markdown]
# 贷款利息从5%到31%

# %%
feature_plot('int_rate', 'Interest Rate', continuous=True)

# %% [markdown]
# 我们从图中信息可知， 贷款利息集中在5%到20%。同时，高利息的申请者坏账比较高

# %%
def outliers_modified_z_score(dataframe, n, features):
    """
    Takes a dataframe df of features and returns a list of the indices corresponding to the observations containing more than n outliers according to the modified z-score Method
    """
    threshold = 3.5
    outlier_indices = []
    for col in features:
        median_y = np.median(dataframe[col])
        median_absolute_deviation_y = np.median([np.abs(y - median_y) for y in dataframe[col]])
        modified_z_scores = [0.6745 * (y - median_y) / median_absolute_deviation_y for y in dataframe[col]]
        outlier_list_col = dataframe[np.abs(modified_z_scores) > threshold].index
       # append the found outlier indices for col to the list of outlier indices 
        outlier_indices.extend(outlier_list_col)
        # select observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    return multiple_outliers

#Outliers_to_drop_z_score = outliers_modified_z_score(df,2,['loan_amnt', 'term', 'int_rate', 'installment', 'annual_inc', 'dti','fico_range_high', 'pub_rec', 'mo_sin_old_il_acct', 'mo_sin_old_rev_tl_op', 'mort_acc','earliest_cr_line_'])

# %%
def outliers_iqr(dataframe, n, features):
    """
    Takes a dataframe df of features and returns a list of the indices
    corresponding to the observations containing more than n outliers according
    to the Tukey method.
    """
    outlier_indices = []
    for col in features:
        # 1st quartile (25%) & # 3rd quartile (75%)
        quartile_1, quartile_3 = np.percentile(dataframe[col], [25,75])
        #quartile_3 = np.percentile(dataframe[col], 75)
      
        iqr = quartile_3 - quartile_1
        lower_bound = quartile_1 - (iqr * 1.5)
        upper_bound = quartile_3 + (iqr * 1.5)
        # Determine a list of indices of outliers for feature col
        outlier_list_col = dataframe[(dataframe[col] < lower_bound) | (dataframe[col] > upper_bound)].index
       # append the found outlier indices for col to the list of outlier indices 
        outlier_indices.extend(outlier_list_col)
        # select observations containing more than 2 outliers
    outlier_indices = Counter(outlier_indices)        
    multiple_outliers = list( k for k, v in outlier_indices.items() if v > n )
    return multiple_outliers

# %%
df.groupby('loan_status')['int_rate'].describe()
# Out:
#                  count       mean       std   min    25%    50%    75%    max
# loan_status
# Charged Off   268559.0  15.710714  4.910387  5.31  12.29  15.05  18.55  30.99
# Fully Paid   1076751.0  12.623288  4.527227  5.31   9.17  12.23  15.31  30.99

# %%
df.loc[(df.int_rate > 15.61) & (df.loan_status == 'Fully Paid')].shape[0]
# Out:
# 234329

# %%
(df.loc[(df.int_rate > 15.61) & (df.loan_status == 'Fully Paid')].shape[0])/df['loan_status'].value_counts(normalize=False, dropna=False)[0]
# Out:
# 0.21762598780962358

# %%
df.loc[(df.int_rate >18.55) & (df.loan_status == 'Charged Off')].shape[0]/df['loan_status'].value_counts(normalize=False, dropna=False)[1]
# Out:
# 0.245521468280713

# %% [markdown]
# 离群点的比例有点大，如果提出这个样本将会损失一部分数据，因此，需要保留这些离群点。

# %% [markdown]
# ### installment

# %%
df['installment'].describe()
# Out:
# count    1.345310e+06
# mean     4.380755e+02
# std      2.615126e+02
# min      4.930000e+00
# 25%      2.484800e+02
# 50%      3.754300e+02
# 75%      5.807300e+02
# max      1.719830e+03
# Name: installment, dtype: float64

# %%
feature_plot('installment', 'Installment', continuous=True)

# %% [markdown]
# 坏账的样本中，每月还款金额相对高比较高，之后将对其进行KS测试进一步比较

# %%
df.groupby('loan_status')['installment'].describe()
# Out:
#                  count        mean         std    min     25%     50%     75%  \
# loan_status
# Charged Off   268559.0  465.147994  262.774106  21.62  275.29  402.83  605.31
# Fully Paid   1076751.0  431.323226  260.759563   4.93  240.92  368.26  573.06
#
#                  max
# loan_status
# Charged Off  1717.63
# Fully Paid   1719.83

# %% [markdown]
# ### grade, sub_grade
# 字段描述：贷款的等级和次等级

# %%
df['grade'].unique().tolist()
# Out:
# ['C', 'B', 'F', 'A', 'E', 'D', 'G']

# %%
print(sorted(df['sub_grade'].unique()))
# Out:
# ['A1', 'A2', 'A3', 'A4', 'A5', 'B1', 'B2', 'B3', 'B4', 'B5', 'C1', 'C2', 'C3', 'C4', 'C5', 'D1', 'D2', 'D3', 'D4', 'D5', 'E1', 'E2', 'E3', 'E4', 'E5', 'F1', 'F2', 'F3', 'F4', 'F5', 'G1', 'G2', 'G3', 'G4', 'G5']

# %% [markdown]
# 由于sub_grade包含grade，因此可以删除grade特征

# %%
feature_plot('sub_grade', 'Subgrade', continuous=False)

# %%
feature_plot('grade','Grade',continuous=False)

# %% [markdown]
# A-G的类别中，坏账率逐渐递增

# %%
df.drop("grade",axis=1,inplace=True)

# %% [markdown]
# ### emp_tilte
# 字段描述：职业

# %%
df['emp_title'].describe()
# Out:
# count     1259525
# unique     378353
# top       Teacher
# freq        21268
# Name: emp_title, dtype: object

# %% [markdown]
# 这个特征头太多类别，我们目前剔除掉它，之后改进可以尝试聚类的方法

# %%
df.drop("emp_title",axis=1,inplace=True)

# %% [markdown]
# ### emp_length
# 字段描述：工作年限

# %%
df["emp_length"].value_counts(dropna=False).sort_index()
# Out:
# 1 year        88494
# 10+ years    442199
# 2 years      121743
# 3 years      107597
# 4 years       80556
# 5 years       84154
# 6 years       62733
# 7 years       59624
# 8 years       60701
# 9 years       50937
# < 1 year     108061
# NaN           78511
# Name: emp_length, dtype: int64

# %% [markdown]
# 有7万多的样本没有缺失这个信息，因此我们需要将其转化为int型特征

# %%
df['emp_length'].replace('10+ years', '10 years', inplace=True)

# %%
df['emp_length'].replace('< 1 year', '0 years', inplace=True)

# %%
df['emp_length'].value_counts(dropna=False).sort_index()
# Out:
# 0 years     108061
# 1 year       88494
# 10 years    442199
# 2 years     121743
# 3 years     107597
# 4 years      80556
# 5 years      84154
# 6 years      62733
# 7 years      59624
# 8 years      60701
# 9 years      50937
# NaN          78511
# Name: emp_length, dtype: int64

# %%
df.emp_length.map( lambda x: str(x).split()[0]).value_counts(dropna=True).sort_index()
# Out:
# 0      108061
# 1       88494
# 10     442199
# 2      121743
# 3      107597
# 4       80556
# 5       84154
# 6       62733
# 7       59624
# 8       60701
# 9       50937
# nan     78511
# Name: emp_length, dtype: int64

# %%
df['emp_length'] = df.emp_length.map( lambda x: float(str(x).split()[0]))

# %%
df['emp_length'].sample(5)
# Out:
# 165964     10.0
# 1847884     5.0
# 1341821     NaN
# 1148733     3.0
# 847135      9.0
# Name: emp_length, dtype: float64

# %%
feature_plot('emp_length', 'Employment length', continuous=False)

# %% [markdown]
# 有三分之一的贷款批准给了过工作年龄超过10年的人，但是跟完全结清的样本属性似乎没有直接联系

# %% [markdown]
# ### home_ownership
# 字段描述：房屋所属情况

# %%
df["home_ownership"].value_counts()
# Out:
# MORTGAGE    665579
# RENT        534421
# OWN         144832
# ANY            286
# OTHER          144
# NONE            48
# Name: home_ownership, dtype: int64

# %%
df['home_ownership'].replace(['NONE','ANY'],'OTHER', inplace=True)

# %%
df['home_ownership'].value_counts()
# Out:
# MORTGAGE    665579
# RENT        534421
# OWN         144832
# OTHER          478
# Name: home_ownership, dtype: int64

# %%
feature_plot("home_ownership", "Home Ownership", continuous=False)

# %%
df.groupby('home_ownership')['loan_status'].value_counts(normalize=True).loc[:,'Charged Off']
# Out:
# home_ownership
# MORTGAGE    0.172077
# OTHER       0.188285
# OWN         0.206198
# RENT        0.232165
# Name: loan_status, dtype: float64

# %% [markdown]
# 有抵押的物对坏账率相对比较低，房子如果是租的话坏账率比较高

# %% [markdown]
# ### annual_inc
# 字段描述：年收入

# %%
df['annual_inc'].describe()
# Out:
# count    1.345310e+06
# mean     7.624764e+04
# std      6.992510e+04
# min      0.000000e+00
# 25%      4.578000e+04
# 50%      6.500000e+04
# 75%      9.000000e+04
# max      1.099920e+07
# Name: annual_inc, dtype: float64

# %%
df['annual_inc'] = df['annual_inc'].apply(lambda x:np.log10(x+1))

# %%
df['annual_inc'].describe()
# Out:
# count    1.345310e+06
# mean     4.812814e+00
# std      2.477200e-01
# min      0.000000e+00
# 25%      4.660685e+00
# 50%      4.812920e+00
# 75%      4.954247e+00
# max      7.041361e+00
# Name: annual_inc, dtype: float64

# %%
feature_plot('annual_inc', 'Log10 Annual income', continuous=True)

# %%
# 进一步分析
df.groupby('loan_status')['annual_inc'].describe()
# Out:
#                  count      mean       std  min       25%       50%       75%  \
# loan_status
# Charged Off   268559.0  4.781756  0.241984  0.0  4.633479  4.778158  4.929424
# Fully Paid   1076751.0  4.820560  0.248526  0.0  4.672107  4.812920  4.968488
#
#                   max
# loan_status
# Charged Off  6.977724
# Fully Paid   7.041361

# %% [markdown]
# ### verication_status
# 字段描述：收入确认状态，有三个状态，’没确认‘，’确认‘和’来源确认’

# %%
df['verification_status'].value_counts()
# Out:
# Source Verified    521273
# Verified           418336
# Not Verified       405701
# Name: verification_status, dtype: int64

# %%
feature_plot('verification_status', 'Verification Status', continuous=False)

# %% [markdown]
# 额， 收入确认了反而坏账更多

# %% [markdown]
# ### purpose
# 字段描述：贷款目的

# %%
df['purpose'].value_counts()
# Out:
# debt_consolidation    780321
# credit_card           295279
# home_improvement       87504
# other                  77875
# major_purchase         29425
# medical                15554
# small_business         15416
# car                    14585
# moving                  9480
# vacation                9065
# house                   7253
# wedding                 2294
# renewable_energy         933
# educational              326
# Name: purpose, dtype: int64

# %%
df.groupby('purpose')['loan_status'].value_counts(normalize=True)[:,'Charged Off'].sort_values(ascending=False)
# Out:
# purpose
# small_business        0.297094
# renewable_energy      0.236870
# moving                0.233544
# house                 0.218806
# medical               0.217757
# debt_consolidation    0.211469
# other                 0.210401
# vacation              0.191726
# major_purchase        0.185998
# home_improvement      0.177158
# educational           0.171779
# credit_card           0.169270
# car                   0.146795
# wedding               0.121622
# Name: loan_status, dtype: float64

# %% [markdown]
# 可以看到，贷款目的为小生(诈)意(骗)的比率比较高

# %% [markdown]
# ### title
# 字段描述：贷款名称

# %%
len(df["title"].unique().tolist())
# Out:
# 61683

# %% [markdown]
# 太多类别了，去掉

# %%
df.drop("title",axis=1,inplace=True)

# %% [markdown]
# 同样地，zip_code太多，需要删掉

# %%
df.drop("zip_code",axis=1,inplace=True)

# %%
df.groupby('addr_state')['loan_status'].value_counts(normalize=True)[:,'Charged Off'].sort_values(ascending=False)
# Out:
# addr_state
# MS    0.260777
# NE    0.251813
# AR    0.240868
# AL    0.236321
# OK    0.234753
# LA    0.231821
# NY    0.220435
# NV    0.219223
# FL    0.214746
# IN    0.214082
# TN    0.214079
# NM    0.213665
# SD    0.213227
# MD    0.213085
# MO    0.212935
# NJ    0.211212
# KY    0.209829
# PA    0.207921
# NC    0.207839
# OH    0.205283
# ND    0.204744
# MI    0.202957
# HI    0.202013
# VA    0.199422
# TX    0.198223
# DE    0.197462
# MN    0.197430
# AK    0.196552
# AZ    0.196299
# CA    0.196104
# MA    0.190528
# ID    0.188277
# GA    0.183927
# WI    0.183510
# IL    0.180974
# RI    0.178675
# CT    0.173763
# UT    0.170586
# MT    0.168716
# WY    0.167693
# KS    0.167438
# SC    0.162769
# WA    0.157565
# CO    0.155269
# WV    0.155187
# NH    0.145759
# OR    0.143850
# IA    0.142857
# VT    0.139517
# ME    0.138424
# DC    0.132086
# Name: loan_status, dtype: float64

# %% [markdown]
# MS坏账率最高，DC最低

# %% [markdown]
# ### dti
# 字段描述：

# %%
df['dti'].describe()
# Out:
# count    1.344936e+06
# mean     1.828267e+01
# std      1.116045e+01
# min     -1.000000e+00
# 25%      1.179000e+01
# 50%      1.761000e+01
# 75%      2.406000e+01
# max      9.990000e+02
# Name: dti, dtype: float64

# %%
f, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12,3), dpi=90)
sns.distplot(df.loc[df['dti'].notnull() & (df['dti'] < 60), 'dti'], kde=False, ax=ax1)
ax1.set_xlabel('dti')
ax1.set_ylabel('Count')
ax1.set_title('debt to income')
sns.boxplot(x=df.loc[df['dti'].notnull() & (df['dti'] < 60), 'dti'], y='loan_status', data=df, ax=ax2)
ax2.set_xlabel('DTI')
ax2.set_ylabel('Fraction of Loans fully paid')
ax2.set_title('Fully paid rate by debt to income')
ax2.set_title('DTI by loan status')
# Out:
# Text(0.5, 1.0, 'DTI by loan status')

# %%
(df['dti'] > 40).sum() / (df['dti']).sum()
# Out:
# 0.0002751635018498183

# %%
(df['dti'] > 40).sum()
# Out:
# 6766

# %% [markdown]
# 离群点比例很低， 除此之外，我们

# %%
df.groupby('loan_status')['dti'].median()
# Out:
# loan_status
# Charged Off    19.76
# Fully Paid     17.11
# Name: dti, dtype: float64

# %% [markdown]
# DTI高的贷款人坏账风险比较高

# %%
df['open_acc'].describe()
# Out:
# count    1.345310e+06
# mean     1.159352e+01
# std      5.473789e+00
# min      0.000000e+00
# 25%      8.000000e+00
# 50%      1.100000e+01
# 75%      1.400000e+01
# max      9.000000e+01
# Name: open_acc, dtype: float64

# %%
feature_plot('open_acc', 'Number of Open Credit Lines', continuous=True)

# %%
df.groupby('loan_status')['open_acc'].describe()
# Out:
#                  count       mean       std  min  25%   50%   75%   max
# loan_status
# Charged Off   268559.0  11.901269  5.637964  0.0  8.0  11.0  15.0  76.0
# Fully Paid   1076751.0  11.516763  5.429354  0.0  8.0  11.0  14.0  90.0

# %% [markdown]
# ### earliest_cr_line
# <a id="earliest_cr_line"></a>
# 字段描述：

# %%
df['earliest_cr_line'].sample(5)
# Out:
# 2073339    Mar-1997
# 338838     Oct-2011
# 1720519    Feb-2011
# 1853680    Sep-2001
# 51324      Jan-2011
# Name: earliest_cr_line, dtype: object

# %%
df['earliest_cr_line'].describe()
# Out:
# count      1345310
# unique         739
# top       Aug-2001
# freq          9391
# Name: earliest_cr_line, dtype: object

# %%
df['earliest_cr_line'].isnull().any()
# Out:
# False

# %%
from datetime import datetime

df.earliest_cr_line = pd.to_datetime(df.earliest_cr_line)

dttoday = datetime.now().strftime('%Y-%m-%d')
df.earliest_cr_line = df.earliest_cr_line.apply(lambda x:(np.timedelta64((x - pd.Timestamp(dttoday)),'D').astype(int))/-365)

df.earliest_cr_line.shape
# Out:
# (1345310,)

# %%
df.earliest_cr_line.sample(5)
# Out:
# 1021609    19.843836
# 693135     11.167123
# 1334460    31.934247
# 944265     21.342466
# 146043     22.342466
# Name: earliest_cr_line, dtype: float64

# %%
feature_plot('earliest_cr_line', 'Length of of the earliest Credit Line (Months to today)', continuous=True)

# %%
df.groupby('loan_status')['earliest_cr_line'].describe()
# Out:
#                  count       mean       std       min        25%        50%  \
# loan_status
# Charged Off   268559.0  20.334492  7.583253  4.583562  15.254795  19.010959
# Fully Paid   1076751.0  21.172695  7.613510  4.416438  15.923288  19.758904
#
#                    75%        max
# loan_status
# Charged Off  24.093151  76.213699
# Fully Paid   25.093151  85.972603

# %% [markdown]
# ### fico_range_low, fico_range_high
# <a id="fico"></a>
# 字段描述：

# %%
df[['fico_range_low','fico_range_high']].describe()
# Out:
#        fico_range_low  fico_range_high
# count    1.345310e+06     1.345310e+06
# mean     6.961850e+02     7.001852e+02
# std      3.185251e+01     3.185316e+01
# min      6.250000e+02     6.290000e+02
# 25%      6.700000e+02     6.740000e+02
# 50%      6.900000e+02     6.940000e+02
# 75%      7.100000e+02     7.140000e+02
# max      8.450000e+02     8.500000e+02

# %%
df[['fico_range_low','fico_range_high']].corr()
# Out:
#                  fico_range_low  fico_range_high
# fico_range_low              1.0              1.0
# fico_range_high             1.0              1.0

# %% [markdown]
# 这两个高度相关，保留一个就可以了

# %%
df['fico_score'] = (df['fico_range_low'] + df['fico_range_high'])/2.

# %%
feature_plot('fico_score', 'FICO Score', continuous=True)

# %% [markdown]
# FICO分数低的有较高违约的风险，我们也看到，有些样本没有FICO值

# %%
import matplotlib.ticker as ticker

fig, (ax1, ax2, ax3) = plt.subplots(3, 1, sharex=False, figsize=(18,10))
sns.distplot(df.loc[df['fico_range_low'].notnull(), 'fico_range_low'], kde=False, ax=ax1)
ax1.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax1.set_ylabel('Count')

sns.distplot(df.loc[df['fico_range_high'].notnull(), 'fico_range_high'], kde=False, ax=ax2)
ax2.xaxis.set_major_locator(ticker.MultipleLocator(5))
ax2.set_ylabel('Count')

sns.distplot(df.loc[df['fico_score'].notnull(), 'fico_score'], kde=False, ax=ax3)
ax3.set_ylabel('Count')
ax3.xaxis.set_major_locator(ticker.MultipleLocator(5))

# %%
df['fico_range_low'].value_counts().sort_index().head(5)
# Out:
# 625.0         1
# 630.0         1
# 660.0    120862
# 665.0    116821
# 670.0    117202
# Name: fico_range_low, dtype: int64

# %%
df['fico_range_high'].value_counts().sort_index().head(5)
# Out:
# 629.0         1
# 634.0         1
# 664.0    120862
# 669.0    116821
# 674.0    117202
# Name: fico_range_high, dtype: int64

# %%
df['fico_score'].value_counts().sort_index().head(5)
# Out:
# 627.0         1
# 632.0         1
# 662.0    120862
# 667.0    116821
# 672.0    117202
# Name: fico_score, dtype: int64

# %%
df[['fico_score','open_acc','earliest_cr_line','dti']].corr()
# Out:
#                   fico_score  open_acc  earliest_cr_line       dti
# fico_score          1.000000  0.017426          0.098915 -0.061928
# open_acc            0.017426  1.000000          0.128078  0.224891
# earliest_cr_line    0.098915  0.128078          1.000000  0.021260
# dti                -0.061928  0.224891          0.021260  1.000000

# %%
plot_df = df.query('fico_score > 650')[:3000]
#sns.set(font_scale=1.2, rc={"lines.linewidth": 1.5}) 
#g = sns.jointplot(x="earliest_cr_line", y="fico_score", data=plot_df, kind='kde')
#g.set(xlim=(2.5, 28),ylim=(630, 880),alpha = .5)
#g.savefig('1.png',transparent=True)

# %%
# %matplotlib inline
# Visualizing 3-D numeric data with Scatter Plots
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

fig = plt.figure(figsize=(13, 6))
#fig, (ax1) = plt.subplots(nrows=1, ncols=1, figsize=(8, 6))
ax1 = fig.add_subplot(121, projection='3d')

xs = plot_df['earliest_cr_line']
ys = plot_df['dti']
zs = plot_df['fico_score']
ax1.scatter(xs, ys, zs, s=50, alpha=0.6, edgecolors='w', cmap='greens')

ax1.set_xlabel('earliest_cr_line')
ax1.set_ylabel('dti')
ax1.set_zlabel('fico_score')
# Out:
# Text(0.5, 0, 'fico_score')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
# Visualizing 3-D numeric data with a bubble chart
plt.scatter(zs, xs, s=ys*5, 
            alpha=0.4, edgecolors='red')

plt.xlabel('FICO score')
plt.ylabel('earliest_cr_line')
plt.title('Fico_score - earliest_cr_line - DTI',y=1.05)
# Out:
# Text(0.5, 1.05, 'Fico_score - earliest_cr_line - DTI')

# %% [markdown]
# FICO分数作为一个很重要的特征，我们来看下FICO，int_rate,term相关性

# %%
df[['fico_score','int_rate','term']].corr()
# Out:
#             fico_score  int_rate      term
# fico_score    1.000000 -0.405365 -0.002222
# int_rate     -0.405365  1.000000  0.417230
# term         -0.002222  0.417230  1.000000

# %% [markdown]
# FICO与利息成负相关

# %%
plot_df = df.query('fico_score > 650 & int_rate <28')[:3000]

sns.set(font_scale=1.2, rc={"lines.linewidth": 1.5}) 

g = sns.lmplot("int_rate", "fico_score", x_jitter= .7,  y_jitter= .1, data=plot_df, hue='term',lowess=True, size=5,aspect=1.4, legend_out=False, scatter_kws={ 's':20, 'alpha':.6})

g.set(xlim=(2.5, 28),ylim=(630, 880),alpha = .5)

#g.savefig('1.png',transparent=True)

# %% [markdown]
# 短期贷款者比较有比较高的FICO分数且利息比较低

# %%
df.drop(['fico_range_high','fico_range_low'],axis=1,inplace=True)

# %% [markdown]
# ### pub_rec
# 字段描述：

# %%
df['pub_rec'].describe()
# Out:
# count    1.345310e+06
# mean     2.152760e-01
# std      6.018647e-01
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      8.600000e+01
# Name: pub_rec, dtype: float64

# %%
df['pub_rec'].value_counts().sort_values(ascending=False)
# Out:
# 0.0     1117425
# 1.0      190789
# 2.0       24435
# 3.0        7399
# 4.0        2630
# 5.0        1266
# 6.0         636
# 7.0         283
# 8.0         160
# 9.0          83
# 10.0         57
# 11.0         40
# 12.0         27
# 13.0         18
# 15.0          9
# 21.0          6
# 18.0          6
# 14.0          5
# 16.0          5
# 19.0          5
# 17.0          3
# 28.0          3
# 20.0          3
# 49.0          2
# 24.0          2
# 22.0          2
# 37.0          1
# 23.0          1
# 40.0          1
# 46.0          1
# 47.0          1
# 25.0          1
# 54.0          1
# 61.0          1
# 63.0          1
# 86.0          1
# 34.0          1
# Name: pub_rec, dtype: int64

# %%
feature_plot('pub_rec','Derogatory public records', continuous=False)

# %% [markdown]
# 我们

# %%
df.groupby('loan_status')['pub_rec'].describe()
# Out:
#                  count      mean       std  min  25%  50%  75%   max
# loan_status
# Charged Off   268559.0  0.246843  0.656732  0.0  0.0  0.0  0.0  86.0
# Fully Paid   1076751.0  0.207403  0.587118  0.0  0.0  0.0  0.0  63.0

# %%
df.pub_rec = df.pub_rec.map(lambda x: 3 if x >2.0 else x)
df['pub_rec'].value_counts().sort_values(ascending=False)
# Out:
# 0.0    1117425
# 1.0     190789
# 2.0      24435
# 3.0      12661
# Name: pub_rec, dtype: int64

# %%
feature_plot('pub_rec','Derogatory public records', continuous=False)

# %%
df.groupby('loan_status')['pub_rec'].describe()
# Out:
#                  count      mean       std  min  25%  50%  75%  max
# loan_status
# Charged Off   268559.0  0.236347  0.537366  0.0  0.0  0.0  0.0  3.0
# Fully Paid   1076751.0  0.198903  0.498270  0.0  0.0  0.0  0.0  3.0

# %% [markdown]
# pub_rec的值为1的贷款者坏账率比较高

# %% [markdown]
# ### pub_rec_bankruptcies
# 字段描述：破产次数

# %%
feature_plot('pub_rec_bankruptcies', 'Number of public record bankruptcies', continuous=False)

# %%
df[['pub_rec','pub_rec_bankruptcies']].corr()
# Out:
#                        pub_rec  pub_rec_bankruptcies
# pub_rec               1.000000              0.735344
# pub_rec_bankruptcies  0.735344              1.000000

# %% [markdown]
# pub_rec和pub_rec_bankruptcies相关性比较高

# %% [markdown]
# ### revol_bal
# 字段描述：信贷周转总额

# %%
df['revol_bal'].describe()
# Out:
# count    1.345310e+06
# mean     1.624811e+04
# std      2.232817e+04
# min      0.000000e+00
# 25%      5.943000e+03
# 50%      1.113400e+04
# 75%      1.975575e+04
# max      2.904836e+06
# Name: revol_bal, dtype: float64

# %%
df['revol_bal'] = df['revol_bal'].apply(lambda x:np.log10(x+1))

# %%
feature_plot('revol_bal', 'Log10 total credit revolving balance', continuous=True)

# %% [markdown]
# ### revol_util
# 字段描述：循环利用率

# %%
df['revol_util'].describe()
# Out:
# count    1.344453e+06
# mean     5.181002e+01
# std      2.452107e+01
# min      0.000000e+00
# 25%      3.340000e+01
# 50%      5.220000e+01
# 75%      7.070000e+01
# max      8.923000e+02
# Name: revol_util, dtype: float64

# %%
feature_plot('revol_util', 'Revolving line utilization rate', continuous=True)

# %%
df.groupby('loan_status')['revol_util'].describe()
# Out:
#                  count       mean        std  min   25%   50%   75%    max
# loan_status
# Charged Off   268379.0  54.758433  23.865982  0.0  37.4  55.5  73.1  366.6
# Fully Paid   1076074.0  51.074671  24.626821  0.0  32.5  51.3  70.1  892.3

# %% [markdown]
# 坏账贷款者的revol_util值比较高

# %% [markdown]
# ### total_acc
# 字段描述：

# %%
df['total_acc'].describe()
# Out:
# count    1.345310e+06
# mean     2.498084e+01
# std      1.199847e+01
# min      2.000000e+00
# 25%      1.600000e+01
# 50%      2.300000e+01
# 75%      3.200000e+01
# max      1.760000e+02
# Name: total_acc, dtype: float64

# %%
feature_plot('total_acc', 'total number of credit lines', continuous=True)

# %% [markdown]
# ### initial_list_status
# 字段描述：贷款初始上市状态

# %%
df['initial_list_status'].value_counts()
# Out:
# w    784010
# f    561300
# Name: initial_list_status, dtype: int64

# %% [markdown]
# 两种类型值比例占一半

# %%
feature_plot('initial_list_status','Initial listing status of the loan', continuous=False)

# %% [markdown]
# ### policy_code
# 字段描述：publicly available policy_code=1; new products not publicly available policy_code=2

# %%
df['policy_code'].value_counts()
# Out:
# 1.0    1345310
# Name: policy_code, dtype: int64

# %% [markdown]
# 只有一种值，删除

# %%
df.drop("policy_code",axis=1, inplace=True)

# %% [markdown]
# ### application_type
# 字段描述：申请了类型，个人申请，还是和其他人一起

# %%
df['application_type'].value_counts()
# Out:
# Individual    1319510
# Joint App       25800
# Name: application_type, dtype: int64

# %%
feature_plot('application_type', 'Application Type', continuous=False)

# %% [markdown]
# 绝大多数为个人申请，多人联合申请的坏账比率比较高

# %% [markdown]
# ### mo_sin_old_il_acct
# 字段描述：Months since oldest bank installment account opened

# %%
df['mo_sin_old_il_acct'].describe()
# Out:
# count    1.239735e+06
# mean     1.257976e+02
# std      5.223336e+01
# min      0.000000e+00
# 25%      9.800000e+01
# 50%      1.290000e+02
# 75%      1.520000e+02
# max      9.990000e+02
# Name: mo_sin_old_il_acct, dtype: float64

# %%
feature_plot('mo_sin_old_il_acct', 'Month Since oldest installment account opened', continuous=True)

# %% [markdown]
# ### mo_sin_old_rev_tl_op
# 字段描述：Months since oldest revolving account opened.

# %%
df['mo_sin_old_rev_tl_op'].describe()
# Out:
# count    1.277782e+06
# mean     1.814760e+02
# std      9.450512e+01
# min      2.000000e+00
# 25%      1.170000e+02
# 50%      1.640000e+02
# 75%      2.300000e+02
# max      8.520000e+02
# Name: mo_sin_old_rev_tl_op, dtype: float64

# %%
feature_plot('mo_sin_old_rev_tl_op', 'Months since oldest revolving account opened', continuous=True)

# %% [markdown]
# ### mort_acc
# 字段描述：抵押账户的数量

# %%
df['mort_acc'].describe()
# Out:
# count    1.298029e+06
# mean     1.670783e+00
# std      2.000444e+00
# min      0.000000e+00
# 25%      0.000000e+00
# 50%      1.000000e+00
# 75%      3.000000e+00
# max      5.100000e+01
# Name: mort_acc, dtype: float64

# %%
feature_plot('mort_acc', 'Number of mortgage accounts', continuous=False)

# %%
df.mort_acc = df.mort_acc.map(lambda x: 6.0 if x > 6.0 else x)

# %%
feature_plot('mort_acc', 'Number of mortgage accounts', continuous=False)

# %% [markdown]
# 这个值越大坏账率比较低

# %%
df.groupby('loan_status')['mort_acc'].describe()
# Out:
#                  count      mean       std  min  25%  50%  75%  max
# loan_status
# Charged Off   261673.0  1.332598  1.683164  0.0  0.0  1.0  2.0  6.0
# Fully Paid   1036356.0  1.683199  1.830426  0.0  0.0  1.0  3.0  6.0

# %% [markdown]
# ## 5. 特征选择二
# 这个过程，我们使用统计的一些工具来进行进一步分析

# %% [markdown]
# ### 5.1 目标变量转化

# %%
df['Charged_Off'] = df['loan_status'].apply(lambda s: np.float(s == 'Charged Off'))
df.drop('loan_status',inplace=True,axis=1)

# %% [markdown]
# ### 5.2 假设检验

# %%
list_float = df.select_dtypes(exclude=['object']).columns

# %%
def run_KS_test(feature):
    dist1 = df.loc[df.Charged_Off == 0,feature]
    dist2 = df.loc[df.Charged_Off == 1,feature]
    print(feature+':')
    print(ks_2samp(dist1,dist2),'\n')

# %%
from statsmodels.stats.proportion import proportions_ztest
def run_proportion_Z_test(feature):
    dist1 = df.loc[df.Charged_Off == 0, feature]
    dist2 = df.loc[df.Charged_Off == 1, feature]
    n1 = len(dist1)
    p1 = dist1.sum()
    n2 = len(dist2)
    p2 = dist2.sum()
    z_score, p_value = proportions_ztest([p1, p2], [n1, n2])
    print(feature+':')
    print('z-score = {}; p-value = {}'.format(z_score, p_value),'\n')

# %%
from scipy.stats import chi2_contingency
def run_chi2_test(df, feature):

    dist1 = df.loc[df.loan_status == 'Fully Paid',feature].value_counts().sort_index().tolist()
    dist2 = df.loc[df.loan_status == 'Charged Off',feature].value_counts().sort_index().tolist()
    chi2, p, dof, expctd = chi2_contingency([dist1,dist2])
    print(feature+':')
    print("chi-square test statistic:", chi2)
    print("p-value", p, '\n')

# %%
for i in list_float:
    run_KS_test(i)
# Out:
# loan_amnt:
# Ks_2sampResult(statistic=0.08341793565761396, pvalue=0.0)
#
# term:
# Ks_2sampResult(statistic=0.1884875690616944, pvalue=0.0)
#
# int_rate:
# Ks_2sampResult(statistic=0.26709123944420854, pvalue=0.0)
#
# installment:
# Ks_2sampResult(statistic=0.07177308649462699, pvalue=0.0)
#
# emp_length:
# Ks_2sampResult(statistic=0.02538830065622577, pvalue=9.11735879570968e-121)
#
# annual_inc:
# Ks_2sampResult(statistic=0.07162968406367032, pvalue=0.0)
#
# dti:
# Ks_2sampResult(statistic=0.11413770318986116, pvalue=0.0)
#
# earliest_cr_line:
# Ks_2sampResult(statistic=0.05478115417211504, pvalue=0.0)
#
# open_acc:
# Ks_2sampResult(statistic=0.02923793065231428, pvalue=4.9928027835478835e-160)
#
# pub_rec:
# Ks_2sampResult(statistic=0.029598859981289527, pvalue=5.414690789546113e-164)
#
# revol_bal:
# Ks_2sampResult(statistic=0.018292907328583796, pvalue=6.685708285584415e-63)
#
# revol_util:
# Ks_2sampResult(statistic=0.06461830322886436, pvalue=0.0)
#
# total_acc:
# Ks_2sampResult(statistic=0.017750078823176307, pvalue=3.0059713277050153e-59)
#
# mo_sin_old_il_acct:
# Ks_2sampResult(statistic=0.03536030133651713, pvalue=7.229532079723465e-234)
#
# mo_sin_old_rev_tl_op:
# Ks_2sampResult(statistic=0.06674118284428288, pvalue=0.0)
#
# mort_acc:
# Ks_2sampResult(statistic=0.09312970723716452, pvalue=0.0)
#
# pub_rec_bankruptcies:
# Ks_2sampResult(statistic=0.020872747616026865, pvalue=9.133854484547676e-82)
#
# fico_score:
# Ks_2sampResult(statistic=0.1386761979596195, pvalue=0.0)
#
# Charged_Off:
# Ks_2sampResult(statistic=1.0, pvalue=0.0)

# %% [markdown]
# ### 5.3 皮尔森系数

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1345310 entries, 0 to 2260697
# Data columns (total 29 columns):
# id                      1345310 non-null object
# loan_amnt               1345310 non-null float64
# term                    1345310 non-null int64
# int_rate                1345310 non-null float64
# installment             1345310 non-null float64
# sub_grade               1345310 non-null object
# emp_length              1266799 non-null float64
# home_ownership          1345310 non-null object
# annual_inc              1345310 non-null float64
# verification_status     1345310 non-null object
# issue_d                 1345310 non-null object
# url                     1345310 non-null object
# purpose                 1345310 non-null object
# addr_state              1345310 non-null object
# dti                     1344936 non-null float64
# earliest_cr_line        1345310 non-null float64
# open_acc                1345310 non-null float64
# pub_rec                 1345310 non-null float64
# revol_bal               1345310 non-null float64
# revol_util              1344453 non-null float64
# total_acc               1345310 non-null float64
# initial_list_status     1345310 non-null object
# application_type        1345310 non-null object
# mo_sin_old_il_acct      1239735 non-null float64
# mo_sin_old_rev_tl_op    1277782 non-null float64
# mort_acc                1298029 non-null float64
# pub_rec_bankruptcies    1344613 non-null float64
# fico_score              1345310 non-null float64
# Charged_Off             1345310 non-null float64
# dtypes: float64(18), int64(1), object(10)
# memory usage: 347.9+ MB

# %%
list_float = df.select_dtypes(exclude=['object']).columns

# %%
list_float
# Out:
# Index(['loan_amnt', 'term', 'int_rate', 'installment', 'emp_length',
#        'annual_inc', 'dti', 'earliest_cr_line', 'open_acc', 'pub_rec',
#        'revol_bal', 'revol_util', 'total_acc', 'mo_sin_old_il_acct',
#        'mo_sin_old_rev_tl_op', 'mort_acc', 'pub_rec_bankruptcies',
#        'fico_score', 'Charged_Off'],
#       dtype='object')

# %%
fig, ax = plt.subplots(figsize=(15,15))         # Sample figsize in inches
cm_df = sns.heatmap(df[list_float].corr(),annot=True, fmt = ".2f", cmap = "coolwarm", ax=ax)

# %% [markdown]
# 线性相关的特征有：
#
# - installment 和 loan_amnt(0.95)
# - mo_sin_old_rev_tl_op 和 earliest_cr_line(0.91)
# - pub_rec_bankruptcies 和 pub_rec (0.74)
# - total_acc 和 open_acc (0.70)
# 其中，mo_sin_old_rev_tl_op 和 pub_rec_bankruptcies有缺失值

# %%
cor = df[list_float].corr()
cor.loc[:,:] = np.tril(cor, k=-1) # below main lower triangle of an array
cor = cor.stack()
cor[(cor > 0.1) | (cor < -0.1)]
# Out:
# term         loan_amnt               0.380905
# int_rate     loan_amnt               0.141673
#              term                    0.417230
# installment  loan_amnt               0.953401
#              term                    0.142858
#                                        ...
# fico_score   mort_acc                0.101790
#              pub_rec_bankruptcies   -0.203341
# Charged_Off  term                    0.176096
#              int_rate                0.258792
#              fico_score             -0.130683
# Length: 88, dtype: float64

# %%
df[["installment","loan_amnt","mo_sin_old_rev_tl_op","earliest_cr_line","total_acc","open_acc", "pub_rec_bankruptcies", "pub_rec"]].isnull().any()
# Out:
# installment             False
# loan_amnt               False
# mo_sin_old_rev_tl_op     True
# earliest_cr_line        False
# total_acc               False
# open_acc                False
# pub_rec_bankruptcies     True
# pub_rec                 False
# dtype: bool

# %%
list_linear = ['installment', 'mo_sin_old_rev_tl_op','total_acc','pub_rec_bankruptcies']

# %%
linear_corr = pd.DataFrame()

# %%
# Pearson系数
for col in df[list_float].columns:
    linear_corr.loc[col, 'pearson_corr'] = df[col].corr(df['Charged_Off'])
linear_corr['abs_pearson_corr'] = abs(linear_corr['pearson_corr'])

# %%
linear_corr.sort_values('abs_pearson_corr', ascending=False, inplace=True)
linear_corr.drop('abs_pearson_corr', axis=1, inplace=True)
linear_corr.drop('Charged_Off', axis=0, inplace=True)

# %%
linear_corr.reset_index(inplace=True)
#linear_corr.rename(columns={'index':'variable'}, inplace=True)

# %% [markdown]
# 表一

# %%
linear_corr
# Out:
#                    index  pearson_corr
# 0               int_rate      0.258792
# 1                   term      0.176096
# 2             fico_score     -0.130683
# 3                    dti      0.084510
# 4               mort_acc     -0.077832
# 5              loan_amnt      0.065604
# 6             annual_inc     -0.062614
# 7             revol_util      0.060048
# 8            installment      0.051701
# 9   mo_sin_old_rev_tl_op     -0.050502
# 10      earliest_cr_line     -0.043999
# 11               pub_rec      0.029548
# 12              open_acc      0.028078
# 13    mo_sin_old_il_acct     -0.026213
# 14  pub_rec_bankruptcies      0.025308
# 15            emp_length     -0.014235
# 16             total_acc     -0.011300
# 17             revol_bal     -0.005929

# %% [markdown]
# The variables most linearly correlated with our target variable are interest rate, loan term, Fico Score and debt-to-income ratio. The least correlated features are the revolving balance, employment length, and public record.

# %%
df.drop(list_linear,axis=1,inplace=True)

# %%
df.shape
# Out:
# (1345310, 25)

# %% [markdown]
# ## 6. 特征工程
# <a id="featureeng"></a>
#
# - One hot 编码
# - [数据集分割](#split)
# - 归一化
# - [PCA](#pca)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1345310 entries, 0 to 2260697
# Data columns (total 25 columns):
# id                     1345310 non-null object
# loan_amnt              1345310 non-null float64
# term                   1345310 non-null int64
# int_rate               1345310 non-null float64
# sub_grade              1345310 non-null object
# emp_length             1266799 non-null float64
# home_ownership         1345310 non-null object
# annual_inc             1345310 non-null float64
# verification_status    1345310 non-null object
# issue_d                1345310 non-null object
# url                    1345310 non-null object
# purpose                1345310 non-null object
# addr_state             1345310 non-null object
# dti                    1344936 non-null float64
# earliest_cr_line       1345310 non-null float64
# open_acc               1345310 non-null float64
# pub_rec                1345310 non-null float64
# revol_bal              1345310 non-null float64
# revol_util             1344453 non-null float64
# initial_list_status    1345310 non-null object
# application_type       1345310 non-null object
# mo_sin_old_il_acct     1239735 non-null float64
# mort_acc               1298029 non-null float64
# fico_score             1345310 non-null float64
# Charged_Off            1345310 non-null float64
# dtypes: float64(14), int64(1), object(10)
# memory usage: 306.9+ MB

# %%
df.sample(5)
# Out:
#                 id  loan_amnt  term  int_rate sub_grade  emp_length  \
# 824245   137999964     6025.0    36     13.56        C1         0.0
# 1900632    1604928    21175.0    36     19.72        D5         7.0
# 1125933   33141214    12000.0    36     12.99        C2         6.0
# 1897731    1688014    18000.0    36     11.14        B2        10.0
# 1744815   96380514     5000.0    36      5.32        A1         5.0
#
#         home_ownership  annual_inc verification_status   issue_d  \
# 824245            RENT    4.176120     Source Verified  Aug-2018
# 1900632       MORTGAGE    4.729982            Verified  Oct-2012
# 1125933       MORTGAGE    4.795192     Source Verified  Nov-2014
# 1897731       MORTGAGE    4.888438            Verified  Nov-2012
# 1744815       MORTGAGE    5.041397            Verified  Jan-2017
#
#                                                        url  \
# 824245   https://lendingclub.com/browse/loanDetail.acti...
# 1900632  https://lendingclub.com/browse/loanDetail.acti...
# 1125933  https://lendingclub.com/browse/loanDetail.acti...
# 1897731  https://lendingclub.com/browse/loanDetail.acti...
# 1744815  https://lendingclub.com/browse/loanDetail.acti...
#
#                     purpose addr_state    dti  earliest_cr_line  open_acc  \
# 824245   debt_consolidation         MA  18.32          4.917808      10.0
# 1900632  debt_consolidation         AZ  14.86         27.430137      17.0
# 1125933  debt_consolidation         MA  24.48         17.424658      12.0
# 1897731  debt_consolidation         CA   9.98         20.260274       5.0
# 1744815  debt_consolidation         CA   1.06         16.008219       7.0
#
#          pub_rec  revol_bal  revol_util initial_list_status application_type  \
# 824245       0.0   3.506505        34.5                   w       Individual
# 1900632      0.0   4.329723        41.3                   f       Individual
# 1125933      0.0   3.994933        44.9                   f       Individual
# 1897731      0.0   3.842110        81.8                   f       Individual
# 1744815      1.0   3.570309        17.1                   f       Individual
#
#          mo_sin_old_il_acct  mort_acc  fico_score  Charged_Off
# 824245                 32.0       0.0       677.0          1.0
# 1900632               243.0       0.0       667.0          1.0
# 1125933                60.0       2.0       687.0          1.0
# 1897731               139.0       3.0       727.0          0.0
# 1744815               154.0       2.0       732.0          0.0

# %% [markdown]
# ### 6.1 类别变量

# %%
dummy_list =['sub_grade','home_ownership','verification_status','purpose','addr_state','initial_list_status','application_type']

# %%
df[dummy_list].isnull().any()
# Out:
# sub_grade              False
# home_ownership         False
# verification_status    False
# purpose                False
# addr_state             False
# initial_list_status    False
# application_type       False
# dtype: bool

# %%
df = pd.get_dummies(df, columns=dummy_list, drop_first=True)

# %%
df.shape
# Out:
# (1345310, 122)

# %%
df.head(1)
# Out:
#          id  loan_amnt  term  int_rate  emp_length  annual_inc   issue_d  \
# 0  68407277     3600.0    36     13.99        10.0    4.740371  Dec-2015
#
#                                                  url   dti  earliest_cr_line  \
# 0  https://lendingclub.com/browse/loanDetail.acti...  5.91         16.591781
#
#    open_acc  pub_rec  revol_bal  revol_util  mo_sin_old_il_acct  mort_acc  \
# 0       7.0      0.0   3.441852        29.7               148.0       1.0
#
#    fico_score  Charged_Off  sub_grade_A2  sub_grade_A3  sub_grade_A4  \
# 0       677.0          0.0             0             0             0
#
#    sub_grade_A5  sub_grade_B1  sub_grade_B2  sub_grade_B3  sub_grade_B4  \
# 0             0             0             0             0             0
#
#    sub_grade_B5  sub_grade_C1  sub_grade_C2  sub_grade_C3  sub_grade_C4  \
# 0             0             0             0             0             1
#
#    sub_grade_C5  sub_grade_D1  sub_grade_D2  sub_grade_D3  sub_grade_D4  \
# 0             0             0             0             0             0
#
#    sub_grade_D5  sub_grade_E1  sub_grade_E2  sub_grade_E3  sub_grade_E4  \
# 0             0             0             0             0             0
#
#    sub_grade_E5  sub_grade_F1  sub_grade_F2  sub_grade_F3  sub_grade_F4  \
# 0             0             0             0             0             0
#
#    sub_grade_F5  sub_grade_G1  sub_grade_G2  sub_grade_G3  sub_grade_G4  \
# 0             0             0             0             0             0
#
#    sub_grade_G5  home_ownership_OTHER  home_ownership_OWN  \
# 0             0                     0                   0
#
#    home_ownership_RENT  verification_status_Source Verified  \
# 0                    0                                    0
#
#    verification_status_Verified  purpose_credit_card  \
# 0                             0                    0
#
#    purpose_debt_consolidation  purpose_educational  purpose_home_improvement  \
# 0                           1                    0                         0
#
#    purpose_house  purpose_major_purchase  purpose_medical  purpose_moving  \
# 0              0                       0                0               0
#
#    purpose_other  purpose_renewable_energy  purpose_small_business  \
# 0              0                         0                       0
#
#    purpose_vacation  purpose_wedding  addr_state_AL  addr_state_AR  \
# 0                 0                0              0              0
#
#    addr_state_AZ  addr_state_CA  addr_state_CO  addr_state_CT  addr_state_DC  \
# 0              0              0              0              0              0
#
#    addr_state_DE  addr_state_FL  addr_state_GA  addr_state_HI  addr_state_IA  \
# 0              0              0              0              0              0
#
#    addr_state_ID  addr_state_IL  addr_state_IN  addr_state_KS  addr_state_KY  \
# 0              0              0              0              0              0
#
#    addr_state_LA  addr_state_MA  addr_state_MD  addr_state_ME  addr_state_MI  \
# 0              0              0              0              0              0
#
#    addr_state_MN  addr_state_MO  addr_state_MS  addr_state_MT  addr_state_NC  \
# 0              0              0              0              0              0
#
#    addr_state_ND  addr_state_NE  addr_state_NH  addr_state_NJ  addr_state_NM  \
# 0              0              0              0              0              0
#
#    addr_state_NV  addr_state_NY  addr_state_OH  addr_state_OK  addr_state_OR  \
# 0              0              0              0              0              0
#
#    addr_state_PA  addr_state_RI  addr_state_SC  addr_state_SD  addr_state_TN  \
# 0              1              0              0              0              0
#
#    addr_state_TX  addr_state_UT  addr_state_VA  addr_state_VT  addr_state_WA  \
# 0              0              0              0              0              0
#
#    addr_state_WI  addr_state_WV  addr_state_WY  initial_list_status_w  \
# 0              0              0              0                      1
#
#    application_type_Joint App
# 0                           0

# %% [markdown]
# ### 6.2 数据集划分
# <a id="split"></a>

# %%
df['issue_d'].sample()
# Out:
# 1038605    Mar-2016
# Name: issue_d, dtype: object

# %%
df['issue_d'].isnull().any()
# Out:
# False

# %%
df['issue_d'] = pd.to_datetime(df['issue_d'])

# %%
df['issue_d'].sample()
# Out:
# 1687026   2017-03-01
# Name: issue_d, dtype: datetime64[ns]

# %%
df['issue_d'].describe()
# Out:
# count                 1345310
# unique                    139
# top       2016-03-01 00:00:00
# freq                    48937
# first     2007-06-01 00:00:00
# last      2018-12-01 00:00:00
# Name: issue_d, dtype: object

# %% [markdown]
# 贷款最早开始于2007年6月，最多在2016年3月，最晚是2018年12月

# %%
plt.figure(figsize=(6,3))
df['issue_d'].dt.year.value_counts().sort_index().plot.bar()
plt.xlabel('Year')
plt.ylabel('Number of loans funded')
plt.title('Loans funded per Year')
# Out:
# Text(0.5, 1.0, 'Loans funded per Year')

# %% [markdown]
# 2012年开始到2015年猛增，之后逐渐下降

# %%
df_train = df.loc[df['issue_d']  < df['issue_d'].quantile(0.8)]
df_test =  df.loc[df['issue_d'] >= df['issue_d'].quantile(0.8)]

# %%
print('Number of loans in the partition:   ', df_train.shape[0] + df_test.shape[0])
print('Number of loans in the full dataset:', df.shape[0])
# Out:
# Number of loans in the partition:    1345310
# Number of loans in the full dataset: 1345310

# %%
df_train['issue_d'].describe()
# Out:
# count                 1062374
# unique                    112
# top       2016-03-01 00:00:00
# freq                    48937
# first     2007-06-01 00:00:00
# last      2016-09-01 00:00:00
# Name: issue_d, dtype: object

# %%
df_test['issue_d'].describe()
# Out:
# count                  282936
# unique                     27
# top       2016-12-01 00:00:00
# freq                    19373
# first     2016-10-01 00:00:00
# last      2018-12-01 00:00:00
# Name: issue_d, dtype: object

# %%
# 删除 issue_d
df_train.drop('issue_d', axis=1, inplace=True)
df_test.drop('issue_d', axis=1, inplace=True)

# %%
X_train = df_train.drop(['Charged_Off'], axis=1)
y_train = df_train.loc[:, 'Charged_Off']

X_test = df_test.drop(['Charged_Off'], axis=1)
y_test = df_test['Charged_Off']

# %%
X_all = df.drop(['Charged_Off'], axis=1)
Y_all = df.loc[:, 'Charged_Off']

# %% [markdown]
# ### 6.3 缺失值填充
# <a id="imputing"></a>

# %%
X_train.drop(["url",'id'],inplace=True,axis=1)
X_test.drop(['url','id'],inplace=True,axis=1)

# %%
#中位数填充
for col in X_train.columns:
    X_train[col].fillna(X_train[col].median(),inplace=True)
    X_test[col].fillna(X_train[col].median(),inplace=True)

# %% [markdown]
# ### 6.4 特征标准化
# <a id="scaling"></a>

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()


scaler.fit(X_train)

X_train = pd.DataFrame(scaler.transform(X_train), columns=X_train.columns)
X_test = pd.DataFrame(scaler.transform(X_test), columns=X_test.columns)

# %% [markdown]
# ### 6.5 PCA
# <a id="pca"></a>

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
principalComponents = pca.fit_transform(X_train.values)
principalDf = pd.DataFrame(data = principalComponents, columns = ['principal component 1', 'principal component 2'])

# %%
principalDf.head(5)
# Out:
#    principal component 1  principal component 2
# 0              -1.206153              -0.042956
# 1               1.330280              -1.157122
# 2               1.555275              -0.711642
# 3               1.817683               1.602701
# 4              -0.325519               0.004345

# %%
y_train_df = pd.DataFrame(data=y_train.values, columns=['Charged_Off'])

# %%
finalDf = pd.concat([principalDf, y_train_df], axis = 1)
finalDf.head(5)
# Out:
#    principal component 1  principal component 2  Charged_Off
# 0              -1.206153              -0.042956          0.0
# 1               1.330280              -1.157122          0.0
# 2               1.555275              -0.711642          0.0
# 3               1.817683               1.602701          0.0
# 4              -0.325519               0.004345          0.0

# %%
# PCA可视化
fig = plt.figure(figsize = (5,5))
ax = fig.add_subplot(1,1,1) 
ax.set_xlabel('Principal Component 1', fontsize = 15)
ax.set_ylabel('Principal Component 2', fontsize = 15)
ax.set_title('2 Component PCA', fontsize = 20)

targets = [0, 1]
colors = ['r', 'g']
for target, color in zip(targets,colors):
    indicesToKeep = finalDf['Charged_Off'] == target
    ax.scatter(finalDf.loc[indicesToKeep, 'principal component 1']
               , finalDf.loc[indicesToKeep, 'principal component 2']
               , c = color
               , s = 1, alpha=0.1)
ax.legend(['Fully Paid', 'Charged Off'], markerscale=5.)
ax.grid()

# %%
pca.explained_variance_ratio_
# Out:
# array([0.02523483, 0.02446403])

# %% [markdown]
# The explained variance tells us how much information (variance) can be attributed to each of the principal components (0.03)

# %% [markdown]
# ### 6.6 线性相关
# <a id="pearson2"></a>

# %%
linear_corr = pd.DataFrame()

# %%
# Pearson系数
for col in X_train.columns:
    linear_corr.loc[col, 'pearson_corr'] = X_train[col].corr(y_train)
linear_corr['abs_pearson_corr'] = abs(linear_corr['pearson_corr'])

# %%
linear_corr.sort_values('abs_pearson_corr', ascending=False, inplace=True)
linear_corr.drop('abs_pearson_corr', axis=1, inplace=True)

# %%
linear_corr.reset_index(inplace=True)
#linear_corr.rename(columns={'index':'variable'}, inplace=True)

# %%
linear_corr.head(10)
# Out:
#                    index  pearson_corr
# 0               int_rate      0.005013
# 1       earliest_cr_line      0.004391
# 2  initial_list_status_w     -0.004307
# 3        purpose_wedding      0.003933
# 4               mort_acc      0.003478
# 5                   term      0.003120
# 6             revol_util      0.002944
# 7                    dti     -0.002922
# 8          addr_state_IA      0.002744
# 9           sub_grade_A3      0.002569

# %%
linear_corr.tail(10)
# Out:
#                           index  pearson_corr
# 108               addr_state_WY     -0.000139
# 109  purpose_debt_consolidation      0.000128
# 110                sub_grade_F3      0.000117
# 111               addr_state_ID      0.000112
# 112               addr_state_SD      0.000104
# 113               addr_state_MO      0.000100
# 114                sub_grade_C2     -0.000093
# 115               addr_state_KS      0.000056
# 116    purpose_home_improvement      0.000012
# 117               addr_state_DC      0.000007

# %% [markdown]
# ## 7. Modeling
# <a id="modeling"></a>
#
# 本节将使用不同的机器学习来构建预测模型，在构建的过程中，我们采用网格搜索的方式进行调参， 交叉验证的方式进行模型选择。
#
# - 逻辑回归
# - XGBoost
# - LightGBM
#
# 由于数据样本严重的不平衡，对于模型的评估，我们是混淆矩阵的和AUC的方式进行评估。

# %%
#交叉验证参数设定
from sklearn.model_selection import KFold
random_state = 42
n_splits = 5

# %% [markdown]
# ### 7.1 逻辑回归
# <a id="logreg"></a>

# %%
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.pipeline import Pipeline

# %%
pipeline_sgdlr = Pipeline([
    ('model', SGDClassifier(loss='log', max_iter=1000, tol=1e-3, random_state=random_state, warm_start=False))
])

# %%
#网格参数搜索
param_grid_sgdlr  = {
    'model__alpha': [10**-5, 10**-1, 10**2],
    'model__penalty': ['l1', 'l2']
}

# %%
grid_sgdlr = GridSearchCV(estimator=pipeline_sgdlr, param_grid=param_grid_sgdlr, scoring='roc_auc', n_jobs=-1, pre_dispatch='2*n_jobs', cv=n_splits, verbose=1, return_train_score=False)
grid_sgdlr.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 6 candidates, totalling 30 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 8 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  30 out of  30 | elapsed:  3.3min finished
# GridSearchCV(cv=5, error_score=nan,
#              estimator=Pipeline(memory=None,
#                                 steps=[('model',
#                                         SGDClassifier(alpha=0.0001,
#                                                       average=False,
#                                                       class_weight=None,
#                                                       early_stopping=False,
#                                                       epsilon=0.1, eta0=0.0,
#                                                       fit_intercept=True,
#                                                       l1_ratio=0.15,
#                                                       learning_rate='optimal',
#                                                       loss='log', max_iter=1000,
#                                                       n_iter_no_change=5,
#                                                       n_jobs=None, penalty='l2',
#                                                       power_t=0.5,
#                                                       random_state=42,
#                                                       shuffle=True, tol=0.001,
#                                                       validation_fraction=0.1,
#                                                       verbose=0,
#                                                       warm_start=False))],
#                                 verbose=False),
#              iid='deprecated', n_jobs=-1,
#              param_grid={'model__alpha': [1e-05, 0.1, 100],
#                          'model__penalty': ['l1', 'l2']},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=False,
#              scoring='roc_auc', verbose=1)

# %%
#pd.DataFrame(grid_sgdlr.cv_results_)

# %%
sgdlr_estimator = grid_sgdlr.best_estimator_
print('Best score: ', grid_sgdlr.best_score_)
print('Best parameters set: \n', grid_sgdlr.best_params_)
# Out:
# Best score:  0.7125574382774391
# Best parameters set:
#  {'model__alpha': 0.1, 'model__penalty': 'l2'}

# %%
y_pred_sgdlr = sgdlr_estimator.predict(X_test)
y_prob_sgdlr = sgdlr_estimator.predict_proba(X_test)[:,1]

# %%
y_train_pred_sgdlr = sgdlr_estimator.predict(X_train)
y_train_prob_sgdlr = sgdlr_estimator.predict_proba(X_train)[:,1]

# %%
#模型中特征系数
LRmodel_l2 = SGDClassifier(loss='log', max_iter=1000, tol=1e-3, random_state=random_state, warm_start=False, alpha=0.1, penalty='l2')

# %%
LRmodel_l2.fit(X_train, y_train)
# Out:
# SGDClassifier(alpha=0.1, average=False, class_weight=None, early_stopping=False,
#               epsilon=0.1, eta0=0.0, fit_intercept=True, l1_ratio=0.15,
#               learning_rate='optimal', loss='log', max_iter=1000,
#               n_iter_no_change=5, n_jobs=None, penalty='l2', power_t=0.5,
#               random_state=42, shuffle=True, tol=0.001, validation_fraction=0.1,
#               verbose=0, warm_start=False)

# %%
temp = sorted(zip(np.round(LRmodel_l2.coef_.reshape(-1),3), X_train.columns.values), key=lambda x: -abs(x[0]))
weight = [x for x, _ in temp]
feature = [x for _, x in temp]

# %%
print("Logistic Regression (L2) Coefficients: Top 10")
pd.DataFrame({'weight': weight}, index = feature).head(10)
# Out:
# Logistic Regression (L2) Coefficients: Top 10
#                      weight
# int_rate              0.186
# term                  0.175
# fico_score           -0.111
# dti                   0.100
# annual_inc           -0.074
# mort_acc             -0.067
# home_ownership_RENT   0.064
# loan_amnt             0.059
# sub_grade_A2         -0.053
# sub_grade_A4         -0.052

# %%
#递归特征排除
from sklearn.feature_selection import RFE
rfe_l2 = RFE(LRmodel_l2, n_features_to_select=1) 
rfe_l2.fit(X_train, y_train)
# Out:
# RFE(estimator=SGDClassifier(alpha=0.1, average=False, class_weight=None,
#                             early_stopping=False, epsilon=0.1, eta0=0.0,
#                             fit_intercept=True, l1_ratio=0.15,
#                             learning_rate='optimal', loss='log', max_iter=1000,
#                             n_iter_no_change=5, n_jobs=None, penalty='l2',
#                             power_t=0.5, random_state=42, shuffle=True,
#                             tol=0.001, validation_fraction=0.1, verbose=0,
#                             warm_start=False),
#     n_features_to_select=1, step=1, verbose=0)

# %%
temp = sorted(zip(map(lambda x: round(x, 4), rfe_l2.ranking_), X_train.columns))
rank = [x for x, _ in temp]
feature = [x for _, x in temp]
print("Logistic Regression (L2) RFE Result: Top 10")
pd.DataFrame({'rank': rank}, index = feature).head(10)
# Out:
# Logistic Regression (L2) RFE Result: Top 10
#                      rank
# int_rate                1
# term                    2
# fico_score              3
# dti                     4
# mort_acc                5
# annual_inc              6
# loan_amnt               7
# home_ownership_RENT     8
# sub_grade_A2            9
# sub_grade_A5           10

# %% [markdown]
# 从两者方式上看，特征的排序结果有一些细微的差别

# %%
import xgboost as xgb

# %%
dtrain=xgb.DMatrix(X_train,label=y_train)
dtest=xgb.DMatrix(X_train,label=y_test)

# %%
new_xgb = xgb.XGBClassifier(n_estimators=250, max_depth=7, 
                            learning_rate=0.005, subsample=0.8, colsample_bytree=0.3,scale_pos_weight=3.0, 
                             silent=True, nthread=-1, seed=0, missing=None,objective='binary:logistic', 
                             reg_alpha=1, reg_lambda=1, 
                             gamma=0, min_child_weight=1, 
                             max_delta_step=0,base_score=0.5)
new_xgb.fit(X_train,y_train)
# Out:
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.3, gamma=0,
#               learning_rate=0.005, max_delta_step=0, max_depth=7,
#               min_child_weight=1, missing=None, n_estimators=250, n_jobs=1,
#               nthread=-1, objective='binary:logistic', random_state=0,
#               reg_alpha=1, reg_lambda=1, scale_pos_weight=3.0, seed=0,
#               silent=True, subsample=0.8, verbosity=1)

# %%
#AUC的结果
pred_prob = new_xgb.predict_proba(X_test)[:,1]
pred = new_xgb.predict(X_test)
roc_auc_score(y_test, pred)
# Out:
# 0.6129265626783845

# %%
import lightgbm as lgb

# %%
train_data = lgb.Dataset(X_train,label=y_train)
param = {
    'num_leaves':150, 
    'objective':'binary',
    'max_depth':7,
    'learning_rate':.05,
    'max_bin':200}
param['metric'] = ['auc', 'binary_logloss']

num_round = 50
lgb = lgb.train(param,train_data,num_round)
ypred2 = lgb.predict(X_test)

# %%
roc_auc_score(y_test, ypred2)
# Out:
# 0.6978546236982635

# %% [markdown]
# ### 模型评估

# %%
from sklearn.metrics import accuracy_score,precision_score,recall_score,f1_score,roc_curve
def evaluation(X_test, Y_test, Y_pred, Y_prob):
    print("--- ROC AUC ---")
    print("Test Set:", roc_auc_score(Y_test, Y_prob))
    
    print("\n--- Accuracy ---")
    print("Test Set:", accuracy_score(Y_test, Y_pred))

    tn, fp, fn, tp = confusion_matrix(Y_test, Y_pred).ravel()
    print("\n--- Confusion Matrix ---")
    print("True Positive:", tp)
    print("False Negative:", fn)
    print("True Negative:", tn)
    print("False Positive:", fp)

    print("\n--- Precision ---")
    print("Test Set:", precision_score(Y_test, Y_pred))

    print("\n--- Recall ---")
    print("Test Set:", recall_score(Y_test, Y_pred))

    print("\n--- F1 Score ---")
    print("Test Set:", f1_score(Y_test, Y_pred))
      
def plot_ROC(X_test, Y_test, Y_prob):
    
    #Y_prob = model.predict_proba(X_test)[:,1]
    fpr, tpr, thresh = roc_curve(Y_test, Y_prob, pos_label=1)
    roc_auc = roc_auc_score(Y_test, Y_prob)
    # These are the points at threshold = 0.1~0.5
    x1 = fpr[(thresh <= 0.5) & (thresh >= 0.1)] 
    x2 = tpr[(thresh <= 0.5) & (thresh >= 0.1)]

    fig = plt.figure()
    plt.plot(fpr, tpr, color='r', lw=2)
    plt.plot([0, 1], [0, 1], color='b', lw=2, linestyle='--')
    plt.plot(x1, x2, color='k', lw=3, label='threshold = 0.1 ~ 0.5')
    plt.xlim([-0.05, 1.05])
    plt.ylim([-0.05, 1.05])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC Curve (Area = {:.2f})'.format(roc_auc))
    plt.legend(loc="lower right")
    plt.show()

# %%
# 逻辑回归模型评估
lr_pred = LRmodel_l2.predict(X_test)
lr_pred_prob = LRmodel_l2.predict_proba(X_test)[:,1]
evaluation(X_test,y_test,lr_pred,lr_pred_prob)
plot_ROC(X_test,y_test,lr_pred_prob)
# Out:
# --- ROC AUC ---
# Test Set: 0.6960010370631621
#
# --- Accuracy ---
# Test Set: 0.7824525687788051
#
# --- Confusion Matrix ---
# True Positive: 2691
# False Negative: 59018
# True Negative: 218693
# False Positive: 2534
#
# --- Precision ---
# Test Set: 0.515023923444976
#
# --- Recall ---
# Test Set: 0.04360790160268356
#
# --- F1 Score ---
# Test Set: 0.08040756566169659

# %%
# XGBoost模型评估
xgb_prob = new_xgb.predict_proba(X_test)[:,1]
xgb_pred = new_xgb.predict(X_test)
evaluation(X_test,y_test,xgb_pred,xgb_prob)
plot_ROC(X_test,y_test,xgb_prob)
# Out:
# --- ROC AUC ---
# Test Set: 0.6985888106672424
#
# --- Accuracy ---
# Test Set: 0.732101959453728
#
# --- Confusion Matrix ---
# True Positive: 24779
# False Negative: 36930
# True Negative: 182359
# False Positive: 38868
#
# --- Precision ---
# Test Set: 0.3893192137885525
#
# --- Recall ---
# Test Set: 0.4015459657424363
#
# --- F1 Score ---
# Test Set: 0.395338077156259

# %%
#LightGBM模型评估
lgb_pred = []
for i in list(ypred2):
    if i > 0.5:
        lgb_pred.append(1)
    else:
        lgb_pred.append(0)
evaluation(X_test,y_test,lgb_pred,ypred2)
plot_ROC(X_test,y_test,ypred2)
# Out:
# --- ROC AUC ---
# Test Set: 0.6978546236982635
#
# --- Accuracy ---
# Test Set: 0.7835305510786892
#
# --- Confusion Matrix ---
# True Positive: 3803
# False Negative: 57906
# True Negative: 217886
# False Positive: 3341
#
# --- Precision ---
# Test Set: 0.5323348264277715
#
# --- Recall ---
# Test Set: 0.06162796350613363
#
# --- F1 Score ---
# Test Set: 0.11046722728130946

# %% [markdown]
# ## 7. 结论
# 对于这三个模型， 因为属于样本不均衡，因此F1score和AUC的值比较有说服力，XGBoost的AUC值比其他两个稍微高一点，F1的值比其他的两个模型高很多，综上XGBoost是比较好的模型。
